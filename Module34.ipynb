# %%
import pandas as pd
course_name = ['Data Science','Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})

# %%
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %% [markdown]
# Q1. Write a code to print the data present in the second row of the dataframe, df.

# %%
df.loc[[1]]
# Out:
#         course_name  duration
# 1  Machine Learning         3

# %% [markdown]
# Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?

# %% [markdown]
# The loc function in pandas is used for accessing rows and columns by labels or boolean arrays, whereas iloc is used for accessing data by integer-based positional indexing.

# %% [markdown]
# Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df
# then find the output for both new_df.loc[2] and new_df.iloc[2].

# %%
new_df = df.reindex([3,0,1,2])

# %%
new_df
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6

# %%
new_df.loc[[2]]
# Out:
#   course_name  duration
# 2    Big Data         6

# %%
new_df.iloc[[2]]
# Out:
#         course_name  duration
# 1  Machine Learning         3

# %% [markdown]
# loc here takes the given or original/initial indices whereas the iloc takes the predefined indices that doesn't change with the changing of order of the data.

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

# %%
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.807241  0.380379  0.118141  0.890289  0.817791  0.275730
# 2  0.448109  0.919461  0.843243  0.575789  0.989532  0.090869
# 3  0.622745  0.711764  0.356615  0.472082  0.401635  0.296146
# 4  0.654905  0.642299  0.351329  0.529265  0.779168  0.977769
# 5  0.884411  0.793808  0.784029  0.792159  0.440192  0.755411
# 6  0.401129  0.040298  0.023030  0.684084  0.675858  0.199605

# %% [markdown]
# Q4. Write a code to find the following statistical measurements for the above dataframe df1:
# (i) mean of each and every column present in the dataframe.
# (ii) standard deviation of column, ‘column_2’

# %%
df1.describe().mean()
# Out:
# column_1    1.251565
# column_2    1.219711
# column_3    1.102983
# column_4    1.264649
# column_5    1.292224
# column_6    1.124664
# dtype: float64

# %%
df1[['column_2']].std()
# Out:
# column_2    0.320408
# dtype: float64

# %% [markdown]
# Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the
# mean of column, column_2.
# If you are getting errors in executing it then explain why.
# [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

# %%
df1.loc[2,['column_2']] = 'demo'
# Out:
# /var/folders/r_/5nhh3cjx6_bc8q0z01s7fp040000gn/T/ipykernel_70592/1096908247.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'demo' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df1.loc[2,['column_2']] = 'demo'

# %%
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.807241  0.380379  0.118141  0.890289  0.817791  0.275730
# 2  0.448109      demo  0.843243  0.575789  0.989532  0.090869
# 3  0.622745  0.711764  0.356615  0.472082  0.401635  0.296146
# 4  0.654905  0.642299  0.351329  0.529265  0.779168  0.977769
# 5  0.884411  0.793808  0.784029  0.792159  0.440192  0.755411
# 6  0.401129  0.040298  0.023030  0.684084  0.675858  0.199605

# %%
df1['column_2'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df1['column_2'].mean()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6225, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6217 @doc(make_doc("mean", ndim=1))
#    6218 def mean(
#    6219     self,
#    (...)
#    6223     **kwargs,
#    6224 ):
# -> 6225     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
#   11993         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994     )
#
# ...

# %% [markdown]
# string can not be added to an integer value. It is a data type mis match error.

# %% [markdown]
# Q6. What do you understand about the windows function in pandas and list the types of windows
# functions?

# %% [markdown]
# The window function provides capabilities for calculating moving statistics through specified windows of the data. Types of window functions include rolling, expanding, and exponentially weighted moving windows, each suited for different types of statistical analysis like moving averages, cumulative sums, or exponential smoothing.

# %% [markdown]
# Q7. Write a code to print only the current month and year at the time of answering this question.

# %%
from datetime import datetime

current_date = datetime.now()
print("Month:", current_date.month, "Year:", current_date.year)
# Out:
# Month: 6 Year: 2024

# %% [markdown]
# Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and
# calculates the difference between them in days, hours, and minutes using Pandas time delta. The
# program should prompt the user to enter the dates and display the result.

# %%
date1 = pd.to_datetime('2023-04-15')

# %%
date2 = pd.to_datetime('2023-04-30')

# %%
delta = date2 - date1

days = delta.days
hours = delta.components.hours
minutes = delta.components.minutes

# %%
print('days : '+str(days))
print('hours : '+str(hours))
print('minutes : '+str(minutes))
# Out:
# days : 15
# hours : 0
# minutes : 0

# %% [markdown]
# Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified
# column to a categorical data type. The program should prompt the user to enter the file path, column
# name, and category order, and then display the sorted data.

# %%
import pandas as pd

def convert_and_sort_csv():
    
    file_path = input("Enter the CSV file path: ")
    column_name = input("Enter the column name to convert to categorical: ")
    category_order = input("Enter the category order, separated by commas (e.g., high,medium,low): ")
    

    df = pd.read_csv(file_path)

    
    category_order = category_order.split(',')  
    df[column_name] = pd.Categorical(df[column_name], categories=category_order, ordered=True)
    df.sort_values(by=column_name, inplace=True)
    return(df)

df_new = convert_and_sort_csv()
# Out:
# Enter the CSV file path:  services.csv
# Enter the column name to convert to categorical:  status
# Enter the category order, separated by commas (e.g., high,medium,low):  active,inactive,defunct

# %%
df_new
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 18  19           19         NaN                       NaN
# 17  18           18         NaN                       NaN
# 16  17           17         NaN                       NaN
# 15  16           16         NaN                       NaN
# 14  15           15         NaN                       NaN
# 13  14           14         NaN                       NaN
# 12  13           13         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 8    9            9         NaN                       NaN
# 7    8            8         NaN                       NaN
# 6    7            7         NaN                       NaN
# 5    6            6         NaN                       NaN
# ...

# %% [markdown]
# Q10. Write a Python program that reads a CSV file containing sales data for different products and
# visualizes the data using a stacked bar chart to show the sales of each product category over time. The
# program should prompt the user to enter the file path and display the chart.

# %%
df = pd.read_csv('Sales_Data.csv')

# %%
def plot_data(path):
    df = pd.read_csv
    df
# Out:
#       Month  Electronics  Clothing  Home Goods  Books
# 0   January         1500      1200         800    400
# 1  February         1800      1400         950    450
# 2     March         1600      1550        1000    500
# 3     April         1700      1300        1100    550
# 4       May         2000      1600        1200    600

# %%
df.set_index('Month',inplace=True)

# %%
df
# Out:
#           Electronics  Clothing  Home Goods  Books
# Month
# January          1500      1200         800    400
# February         1800      1400         950    450
# March            1600      1550        1000    500
# April            1700      1300        1100    550
# May              2000      1600        1200    600

# %%
df.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write
# a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and
# displays the results in a table.

# %%
def class_stats():
    path = str(input("Enter the file path: "))
    class_data = pd.read_csv(path)
    mean = class_data['Test Score'].mean()
    median = class_data['Test Score'].median()
    mode = class_data['Test Score'].mode()

    return (pd.DataFrame({'mean':mean,'median':median,'mode':mode}))

# %%
class_stats()
# Out:
# Enter the file path:  Student_Test_Scores.csv
#    mean  median  mode
# 0  87.0    85.0    85
